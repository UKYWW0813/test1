# %% [markdown]
# <a href="https://colab.research.google.com/github/UKYWW0813/test1/blob/main/Learning1_GH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # this is learning 101
# ⚓
# [link to Kaggle](https://https://www.kaggle.com/)
#
# *   List item [competition](https://https://www.kaggle.com/competitions)
# *   List item

# %%
print('hello workd')
# Out:
# hello workd

# %% [markdown]
# Read file from Kaggle dataset

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load from the Kaggle dataset
# You need to replace "finance_economics_dataset.csv" with the actual path to the file in the dataset.
# You can find the file paths by browsing the dataset on Kaggle.
file_path = "finance_economics_dataset.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "khushikyad001/finance-and-economics-dataset-2000-present",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /tmp/ipython-input-860477382.py:12: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(
# ...
# 100%|██████████| 470k/470k [00:00<00:00, 535kB/s]
# First 5 records:          Date Stock Index  Open Price  Close Price  Daily High  Daily Low  \
# 0  2000-01-01   Dow Jones     2128.75      2138.48     2143.70    2100.55
# 1  2000-01-02     S&P 500     2046.82      2036.18     2082.83    2009.53
# 2  2000-01-03   Dow Jones     1987.92      1985.26     2022.28    1978.37
# 3  2000-01-04   Dow Jones     4625.02      4660.47     4665.26    4595.46
# 4  2000-01-05     S&P 500     1998.18      1982.18     2044.31    1966.44
#
#    Trading Volume  GDP Growth (%)  Inflation Rate (%)  Unemployment Rate (%)  \
# 0         2670411           -0.37                6.06                   6.10
# 1       690220415            3.19                4.95                   6.62
# ...

# %%
df.head()
# Out:
#          Date Stock Index  Open Price  Close Price  Daily High  Daily Low  \
# 0  2000-01-01   Dow Jones     2128.75      2138.48     2143.70    2100.55
# 1  2000-01-02     S&P 500     2046.82      2036.18     2082.83    2009.53
# 2  2000-01-03   Dow Jones     1987.92      1985.26     2022.28    1978.37
# 3  2000-01-04   Dow Jones     4625.02      4660.47     4665.26    4595.46
# 4  2000-01-05     S&P 500     1998.18      1982.18     2044.31    1966.44
#
#    Trading Volume  GDP Growth (%)  Inflation Rate (%)  Unemployment Rate (%)  \
# 0         2670411           -0.37                6.06                   6.10
# 1       690220415            3.19                4.95                   6.62
# 2       315284661            5.54                9.13                   2.60
# 3        13098297           10.00                3.77                   2.20
# 4       385306746            1.53                2.20                   8.20
#
# ...

# %% [markdown]
# Read file from URL link

# %%
# !wget https://www.stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2024-financial-year-provisional/Download-data/annual-enterprise-survey-2024-financial-year-provisional.csv
# Out:
# --2025-09-01 20:09:05--  https://www.stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2024-financial-year-provisional/Download-data/annual-enterprise-survey-2024-financial-year-provisional.csv
# Resolving www.stats.govt.nz (www.stats.govt.nz)... 45.60.15.134
# Connecting to www.stats.govt.nz (www.stats.govt.nz)|45.60.15.134|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8795771 (8.4M) [application/octet-stream]
# Saving to: ‘annual-enterprise-survey-2024-financial-year-provisional.csv.1’
#
# annual-enterprise-s 100%[===================>]   8.39M  --.-KB/s    in 0.05s
#
# 2025-09-01 20:09:06 (162 MB/s) - ‘annual-enterprise-survey-2024-financial-year-provisional.csv.1’ saved [8795771/8795771]

# %%
# !ls
# Out:
# annual-enterprise-survey-2024-financial-year-provisional.csv	sample_data
# annual-enterprise-survey-2024-financial-year-provisional.csv.1

# %%
import pandas as pd

# %%
pd.read_csv('annual-enterprise-survey-2024-financial-year-provisional.csv')
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2024                     Level 1                99999
# 1      2024                     Level 1                99999
# 2      2024                     Level 1                99999
# 3      2024                     Level 1                99999
# 4      2024                     Level 1                99999
# ...     ...                         ...                  ...
# 55615  2013                     Level 3                 ZZ11
# 55616  2013                     Level 3                 ZZ11
# 55617  2013                     Level 3                 ZZ11
# 55618  2013                     Level 3                 ZZ11
# 55619  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# Mount Google Drive and read file from mounted drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pd.read_csv('/content/drive/MyDrive/Codes/finance_economics_dataset.csv')
# Out:
#             Date Stock Index  Open Price  Close Price  Daily High  Daily Low  \
# 0     2000-01-01   Dow Jones     2128.75      2138.48     2143.70    2100.55
# 1     2000-01-02     S&P 500     2046.82      2036.18     2082.83    2009.53
# 2     2000-01-03   Dow Jones     1987.92      1985.26     2022.28    1978.37
# 3     2000-01-04   Dow Jones     4625.02      4660.47     4665.26    4595.46
# 4     2000-01-05     S&P 500     1998.18      1982.18     2044.31    1966.44
# ...          ...         ...         ...          ...         ...        ...
# 2995  2008-03-14   Dow Jones     1273.76      1235.44     1317.28    1192.34
# 2996  2008-03-15     S&P 500     4589.59      4566.91     4607.56    4545.69
# 2997  2008-03-16     S&P 500     1477.52      1448.47     1523.86    1402.69
# 2998  2008-03-17      NASDAQ     2311.37      2306.90     2346.30    2282.00
# 2999  2008-03-18      NASDAQ     4262.98      4303.82     4316.68    4243.04
#
# ...

# %% [markdown]
# Read file from local drive

# %%
pd.read_csv('/content/annual-enterprise_TEST.csv')
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2024                     Level 1                99999
# 1      2024                     Level 1                99999
# 2      2024                     Level 1                99999
# 3      2024                     Level 1                99999
# 4      2024                     Level 1                99999
# ...     ...                         ...                  ...
# 55615  2013                     Level 3                 ZZ11
# 55616  2013                     Level 3                 ZZ11
# 55617  2013                     Level 3                 ZZ11
# 55618  2013                     Level 3                 ZZ11
# 55619  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# Hello test
# $$  x^2  $$
#
# $ this is a test^3 $

# %%
# !ls /bin
# Out:
# '['				      migrate-pubring-from-classic-gpg
#  7z				      mingle
#  7za				      mispipe
#  7zr				      mkdir
#  aclocal			      mkfifo
#  aclocal-1.16			      mknod
#  acyclic			      mktemp
#  add-apt-repository		      mm2gv
#  addpart			      more
#  addr2line			      mount
#  aggregate_profile		      mountpoint
#  ambiguous_words		      mpexpand
#  apropos			      mpic++
#  apt				      mpicc
#  apt-add-repository		      mpiCC
#  apt-cache			      mpicc.openmpi
#  apt-cdrom			      mpiCC.openmpi
#  apt-config			      mpic++.openmpi
#  apt-extracttemplates		      mpicxx
#  apt-ftparchive			      mpicxx.openmpi
#  apt-get			      mpiexec
#  apt-key			      mpiexec.openmpi
#  apt-mark			      mpif77
#  apt-sortpkgs			      mpif77.openmpi
#  ar				      mpif90
#  arch				      mpif90.openmpi
#  as				      mpifort
#  asan_symbolize			      mpifort.openmpi
#  asan_symbolize-14		      mpijavac
#  autoconf			      mpijavac.pl
#  autoheader			      mpirun
# ...

# %%
# !pwd
# !date
# Out:
# /content
# Mon Sep  1 09:22:18 PM UTC 2025
